# %% [markdown]
# <a href="https://colab.research.google.com/github/alexfomin1/data_visualization/blob/main/visualization_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib

# %%
url = 'https://raw.githubusercontent.com/jsulopzs/data/main/football_players_stats.json'
df_ftbl = pd.read_json(url, orient='index')

# %%
df_ftbl.Goals.plot.pie()

# %%
url = 'https://raw.githubusercontent.com/jsulopzs/data/main/best_tennis_players_stats.json'
df_tennis = pd.read_json(path_or_buf=url, orient='index')

# %%
df_tennis.style.background_gradient()
# Out:
# <style type="text/css">
# #T_40d4c_row0_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_40d4c_row0_col1, #T_40d4c_row0_col4, #T_40d4c_row0_col5, #T_40d4c_row1_col2, #T_40d4c_row2_col0, #T_40d4c_row2_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_40d4c_row0_col2, #T_40d4c_row0_col3, #T_40d4c_row1_col0, #T_40d4c_row2_col1, #T_40d4c_row2_col2, #T_40d4c_row2_col4, #T_40d4c_row2_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_40d4c_row1_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_40d4c_row1_col3 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_40d4c_row1_col4 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_40d4c_row1_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# </style>
# <table id="T_40d4c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >income</th>
#       <th class="col_heading level0 col1" >titles</th>
#       <th class="col_heading level0 col2" >grand slams</th>
#       <th class="col_heading level0 col3" >turned professional</th>
#       <th class="col_heading level0 col4" >wins</th>
#       <th class="col_heading level0 col5" >losses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40d4c_level0_row0" class="row_heading level0 row0" >roger</th>
#       <td id="T_40d4c_row0_col0" class="data row0 col0" >130</td>
#       <td id="T_40d4c_row0_col1" class="data row0 col1" >103</td>
#       <td id="T_40d4c_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_40d4c_row0_col3" class="data row0 col3" >1998</td>
#       <td id="T_40d4c_row0_col4" class="data row0 col4" >1251</td>
#       <td id="T_40d4c_row0_col5" class="data row0 col5" >275</td>
#     </tr>
#     <tr>
#       <th id="T_40d4c_level0_row1" class="row_heading level0 row1" >rafa</th>
#       <td id="T_40d4c_row1_col0" class="data row1 col0" >127</td>
#       <td id="T_40d4c_row1_col1" class="data row1 col1" >90</td>
#       <td id="T_40d4c_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_40d4c_row1_col3" class="data row1 col3" >2001</td>
#       <td id="T_40d4c_row1_col4" class="data row1 col4" >1038</td>
#       <td id="T_40d4c_row1_col5" class="data row1 col5" >209</td>
#     </tr>
#     <tr>
#       <th id="T_40d4c_level0_row2" class="row_heading level0 row2" >nole</th>
#       <td id="T_40d4c_row2_col0" class="data row2 col0" >154</td>
#       <td id="T_40d4c_row2_col1" class="data row2 col1" >86</td>
#       <td id="T_40d4c_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_40d4c_row2_col3" class="data row2 col3" >2003</td>
#       <td id="T_40d4c_row2_col4" class="data row2 col4" >989</td>
#       <td id="T_40d4c_row2_col5" class="data row2 col5" >199</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_tennis.plot.pie(subplots=True, layout=(2,3), figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd882452c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd88125f7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd8812d2dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8811a2cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd88115afd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd88111e390>]],
#       dtype=object)

# %%
df_laliga = pd.read_html('https://www.skysports.com/la-liga-table/2021', index_col='Team')[0]

# %%
df_laliga.Pts.sort_values().plot.barh()

# %%
url = 'https://raw.githubusercontent.com/jsulopzs/data/main/internet_usage_spain.csv'
df_internet = pd.read_csv(filepath_or_buffer=url)

# %%
df_internet.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd880231390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd88023e350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8801891d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd8801bc7d0>]],
#       dtype=object)

# %%
dfres = df_internet.pivot_table(index='education', columns='internet_usage', aggfunc='size')

# %%
dfres.style.background_gradient('Greens', axis=1)
# Out:
# <style type="text/css">
# #T_11667_row0_col0, #T_11667_row1_col1, #T_11667_row2_col1, #T_11667_row3_col0, #T_11667_row4_col1, #T_11667_row5_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_11667_row0_col1, #T_11667_row1_col0, #T_11667_row2_col0, #T_11667_row3_col1, #T_11667_row4_col0, #T_11667_row5_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_11667_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >internet_usage</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11667_level0_row0" class="row_heading level0 row0" >Elementary</th>
#       <td id="T_11667_row0_col0" class="data row0 col0" >780</td>
#       <td id="T_11667_row0_col1" class="data row0 col1" >404</td>
#     </tr>
#     <tr>
#       <th id="T_11667_level0_row1" class="row_heading level0 row1" >High School</th>
#       <td id="T_11667_row1_col0" class="data row1 col0" >58</td>
#       <td id="T_11667_row1_col1" class="data row1 col1" >221</td>
#     </tr>
#     <tr>
#       <th id="T_11667_level0_row2" class="row_heading level0 row2" >Higher Level</th>
#       <td id="T_11667_row2_col0" class="data row2 col0" >88</td>
#       <td id="T_11667_row2_col1" class="data row2 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_11667_level0_row3" class="row_heading level0 row3" >No studies</th>
#       <td id="T_11667_row3_col0" class="data row3 col0" >176</td>
#       <td id="T_11667_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_11667_level0_row4" class="row_heading level0 row4" >PhD</th>
#       <td id="T_11667_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_11667_row4_col1" class="data row4 col1" >222</td>
#     </tr>
#     <tr>
#       <th id="T_11667_level0_row5" class="row_heading level0 row5" >University</th>
#       <td id="T_11667_row5_col0" class="data row5 col0" >24</td>
#       <td id="T_11667_row5_col1" class="data row5 col1" >181</td>
#     </tr>
#   </tbody>
# </table>
