# %% [markdown]
# <a href="https://colab.research.google.com/github/alexfomin1/data_visualization/blob/main/tables_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
df_tips = sns.load_dataset('tips')
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_tips.groupby(by=['day', 'time'])\
    .mean()\
    .fillna(0)\
    .style.format('{:.2f}').background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_193bb_row0_col0 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_193bb_row0_col1 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_193bb_row0_col2 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_193bb_row1_col0 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_193bb_row1_col1, #T_193bb_row3_col0, #T_193bb_row5_col1 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_193bb_row1_col2, #T_193bb_row2_col2 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_193bb_row2_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_193bb_row2_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_193bb_row3_col1 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_193bb_row3_col2 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_193bb_row4_col0, #T_193bb_row4_col1, #T_193bb_row4_col2, #T_193bb_row6_col0, #T_193bb_row6_col1, #T_193bb_row6_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_193bb_row5_col0 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_193bb_row5_col2 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_193bb_row7_col0, #T_193bb_row7_col1, #T_193bb_row7_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_193bb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_bill</th>
#       <th class="col_heading level0 col1" >tip</th>
#       <th class="col_heading level0 col2" >size</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="index_name level1" >time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_193bb_level0_row0" class="row_heading level0 row0" rowspan="2">Thur</th>
#       <th id="T_193bb_level1_row0" class="row_heading level1 row0" >Lunch</th>
#       <td id="T_193bb_row0_col0" class="data row0 col0" >17.66</td>
#       <td id="T_193bb_row0_col1" class="data row0 col1" >2.77</td>
#       <td id="T_193bb_row0_col2" class="data row0 col2" >2.46</td>
#     </tr>
#     <tr>
#       <th id="T_193bb_level1_row1" class="row_heading level1 row1" >Dinner</th>
#       <td id="T_193bb_row1_col0" class="data row1 col0" >18.78</td>
#       <td id="T_193bb_row1_col1" class="data row1 col1" >3.00</td>
#       <td id="T_193bb_row1_col2" class="data row1 col2" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_193bb_level0_row2" class="row_heading level0 row2" rowspan="2">Fri</th>
#       <th id="T_193bb_level1_row2" class="row_heading level1 row2" >Lunch</th>
#       <td id="T_193bb_row2_col0" class="data row2 col0" >12.85</td>
#       <td id="T_193bb_row2_col1" class="data row2 col1" >2.38</td>
#       <td id="T_193bb_row2_col2" class="data row2 col2" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_193bb_level1_row3" class="row_heading level1 row3" >Dinner</th>
#       <td id="T_193bb_row3_col0" class="data row3 col0" >19.66</td>
#       <td id="T_193bb_row3_col1" class="data row3 col1" >2.94</td>
#       <td id="T_193bb_row3_col2" class="data row3 col2" >2.17</td>
#     </tr>
#     <tr>
#       <th id="T_193bb_level0_row4" class="row_heading level0 row4" rowspan="2">Sat</th>
#       <th id="T_193bb_level1_row4" class="row_heading level1 row4" >Lunch</th>
#       <td id="T_193bb_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_193bb_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_193bb_row4_col2" class="data row4 col2" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_193bb_level1_row5" class="row_heading level1 row5" >Dinner</th>
#       <td id="T_193bb_row5_col0" class="data row5 col0" >20.44</td>
#       <td id="T_193bb_row5_col1" class="data row5 col1" >2.99</td>
#       <td id="T_193bb_row5_col2" class="data row5 col2" >2.52</td>
#     </tr>
#     <tr>
#       <th id="T_193bb_level0_row6" class="row_heading level0 row6" rowspan="2">Sun</th>
#       <th id="T_193bb_level1_row6" class="row_heading level1 row6" >Lunch</th>
#       <td id="T_193bb_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_193bb_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_193bb_row6_col2" class="data row6 col2" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_193bb_level1_row7" class="row_heading level1 row7" >Dinner</th>
#       <td id="T_193bb_row7_col0" class="data row7 col0" >21.41</td>
#       <td id="T_193bb_row7_col1" class="data row7 col1" >3.26</td>
#       <td id="T_193bb_row7_col2" class="data row7 col2" >2.84</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_tips.groupby(by=['day', 'time'])\
    .mean()\
    .fillna(0)\
    .style.format('{:.2f}').bar(axis=0, width=50, align='zero')
# Out:
# <style type="text/css">
# #T_627bc_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 45.6%, transparent 45.6%);
# }
# #T_627bc_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 46.3%, transparent 46.3%);
# }
# #T_627bc_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 46.6%, transparent 46.6%);
# }
# #T_627bc_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 46.9%, transparent 46.9%);
# }
# #T_627bc_row1_col1, #T_627bc_row3_col0, #T_627bc_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 48.0%, transparent 48.0%);
# }
# #T_627bc_row1_col2, #T_627bc_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 42.6%, transparent 42.6%);
# }
# #T_627bc_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 40.0%, transparent 40.0%);
# }
# #T_627bc_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 43.3%, transparent 43.3%);
# }
# #T_627bc_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 47.6%, transparent 47.6%);
# }
# #T_627bc_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 44.1%, transparent 44.1%);
# }
# #T_627bc_row4_col0, #T_627bc_row4_col1, #T_627bc_row4_col2, #T_627bc_row6_col0, #T_627bc_row6_col1, #T_627bc_row6_col2 {
#   width: 10em;
#   height: 80%;
# }
# #T_627bc_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 48.9%, transparent 48.9%);
# }
# #T_627bc_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 47.1%, transparent 47.1%);
# }
# #T_627bc_row7_col0, #T_627bc_row7_col1, #T_627bc_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.0%, #d65f5f 25.0%, #d65f5f 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_627bc_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_bill</th>
#       <th class="col_heading level0 col1" >tip</th>
#       <th class="col_heading level0 col2" >size</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="index_name level1" >time</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_627bc_level0_row0" class="row_heading level0 row0" rowspan="2">Thur</th>
#       <th id="T_627bc_level1_row0" class="row_heading level1 row0" >Lunch</th>
#       <td id="T_627bc_row0_col0" class="data row0 col0" >17.66</td>
#       <td id="T_627bc_row0_col1" class="data row0 col1" >2.77</td>
#       <td id="T_627bc_row0_col2" class="data row0 col2" >2.46</td>
#     </tr>
#     <tr>
#       <th id="T_627bc_level1_row1" class="row_heading level1 row1" >Dinner</th>
#       <td id="T_627bc_row1_col0" class="data row1 col0" >18.78</td>
#       <td id="T_627bc_row1_col1" class="data row1 col1" >3.00</td>
#       <td id="T_627bc_row1_col2" class="data row1 col2" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_627bc_level0_row2" class="row_heading level0 row2" rowspan="2">Fri</th>
#       <th id="T_627bc_level1_row2" class="row_heading level1 row2" >Lunch</th>
#       <td id="T_627bc_row2_col0" class="data row2 col0" >12.85</td>
#       <td id="T_627bc_row2_col1" class="data row2 col1" >2.38</td>
#       <td id="T_627bc_row2_col2" class="data row2 col2" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_627bc_level1_row3" class="row_heading level1 row3" >Dinner</th>
#       <td id="T_627bc_row3_col0" class="data row3 col0" >19.66</td>
#       <td id="T_627bc_row3_col1" class="data row3 col1" >2.94</td>
#       <td id="T_627bc_row3_col2" class="data row3 col2" >2.17</td>
#     </tr>
#     <tr>
#       <th id="T_627bc_level0_row4" class="row_heading level0 row4" rowspan="2">Sat</th>
#       <th id="T_627bc_level1_row4" class="row_heading level1 row4" >Lunch</th>
#       <td id="T_627bc_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_627bc_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_627bc_row4_col2" class="data row4 col2" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_627bc_level1_row5" class="row_heading level1 row5" >Dinner</th>
#       <td id="T_627bc_row5_col0" class="data row5 col0" >20.44</td>
#       <td id="T_627bc_row5_col1" class="data row5 col1" >2.99</td>
#       <td id="T_627bc_row5_col2" class="data row5 col2" >2.52</td>
#     </tr>
#     <tr>
#       <th id="T_627bc_level0_row6" class="row_heading level0 row6" rowspan="2">Sun</th>
#       <th id="T_627bc_level1_row6" class="row_heading level1 row6" >Lunch</th>
#       <td id="T_627bc_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_627bc_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_627bc_row6_col2" class="data row6 col2" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_627bc_level1_row7" class="row_heading level1 row7" >Dinner</th>
#       <td id="T_627bc_row7_col0" class="data row7 col0" >21.41</td>
#       <td id="T_627bc_row7_col1" class="data row7 col1" >3.26</td>
#       <td id="T_627bc_row7_col2" class="data row7 col2" >2.84</td>
#     </tr>
#   </tbody>
# </table>

# %%
len(df_tips.groupby('sex'))
# Out:
# 2

# %%
df_tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
df_grouped = df_tips.groupby('sex')

# %%
df_grouped.get_group('Female')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
df_grouped.get_group('Female').mean(numeric_only=True)
# Out:
# total_bill    18.056897
# tip            2.833448
# size           2.459770
# dtype: float64

# %%
df_grouped.total_bill.sum()
# Out:
# sex
# Male      3256.82
# Female    1570.95
# Name: total_bill, dtype: float64

# %%
df_grouped.get_group('Female').total_bill.sum()
# Out:
# 1570.9499999999996

# %%
df_tips.groupby(by=['day', 'smoker']).sum()
# Out:
#              total_bill     tip  size
# day  smoker
# Thur Yes         326.24   51.51    40
#      No          770.09  120.32   112
# Fri  Yes         252.20   40.71    31
#      No           73.68   11.25     9
# Sat  Yes         893.62  120.77   104
#      No          884.78  139.63   115
# Sun  Yes         458.28   66.82    49
#      No         1168.88  180.57   167

# %%
df_tips.pivot_table(index='day', columns='smoker', aggfunc='sum')
# Out:
#        size          tip         total_bill
# smoker  Yes   No     Yes      No        Yes       No
# day
# Thur     40  112   51.51  120.32     326.24   770.09
# Fri      31    9   40.71   11.25     252.20    73.68
# Sat     104  115  120.77  139.63     893.62   884.78
# Sun      49  167   66.82  180.57     458.28  1168.88

# %%
dfres = df_tips.pivot_table(index='day', columns='smoker', values='total_bill', aggfunc=['sum', 'mean'])

# %%
dfres.style.background_gradient()
# Out:
# <style type="text/css">
# #T_3dc17_row0_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_3dc17_row0_col1 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_3dc17_row0_col2 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_3dc17_row0_col3, #T_3dc17_row1_col0, #T_3dc17_row1_col1, #T_3dc17_row1_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3dc17_row1_col3 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_3dc17_row2_col0, #T_3dc17_row3_col1, #T_3dc17_row3_col2, #T_3dc17_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3dc17_row2_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_3dc17_row2_col2 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_3dc17_row2_col3 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_3dc17_row3_col0 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# </style>
# <table id="T_3dc17_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">sum</th>
#       <th class="col_heading level0 col2" colspan="2">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >smoker</th>
#       <th class="col_heading level1 col0" >Yes</th>
#       <th class="col_heading level1 col1" >No</th>
#       <th class="col_heading level1 col2" >Yes</th>
#       <th class="col_heading level1 col3" >No</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dc17_level0_row0" class="row_heading level0 row0" >Thur</th>
#       <td id="T_3dc17_row0_col0" class="data row0 col0" >326.240000</td>
#       <td id="T_3dc17_row0_col1" class="data row0 col1" >770.090000</td>
#       <td id="T_3dc17_row0_col2" class="data row0 col2" >19.190588</td>
#       <td id="T_3dc17_row0_col3" class="data row0 col3" >17.113111</td>
#     </tr>
#     <tr>
#       <th id="T_3dc17_level0_row1" class="row_heading level0 row1" >Fri</th>
#       <td id="T_3dc17_row1_col0" class="data row1 col0" >252.200000</td>
#       <td id="T_3dc17_row1_col1" class="data row1 col1" >73.680000</td>
#       <td id="T_3dc17_row1_col2" class="data row1 col2" >16.813333</td>
#       <td id="T_3dc17_row1_col3" class="data row1 col3" >18.420000</td>
#     </tr>
#     <tr>
#       <th id="T_3dc17_level0_row2" class="row_heading level0 row2" >Sat</th>
#       <td id="T_3dc17_row2_col0" class="data row2 col0" >893.620000</td>
#       <td id="T_3dc17_row2_col1" class="data row2 col1" >884.780000</td>
#       <td id="T_3dc17_row2_col2" class="data row2 col2" >21.276667</td>
#       <td id="T_3dc17_row2_col3" class="data row2 col3" >19.661778</td>
#     </tr>
#     <tr>
#       <th id="T_3dc17_level0_row3" class="row_heading level0 row3" >Sun</th>
#       <td id="T_3dc17_row3_col0" class="data row3 col0" >458.280000</td>
#       <td id="T_3dc17_row3_col1" class="data row3 col1" >1168.880000</td>
#       <td id="T_3dc17_row3_col2" class="data row3 col2" >24.120000</td>
#       <td id="T_3dc17_row3_col3" class="data row3 col3" >20.506667</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_tips.pivot_table(
    index='sex',
    columns='time',
    aggfunc=['sum', 'mean'],
    values='total_bill'
)
# Out:
#            sum                mean
# time     Lunch   Dinner      Lunch     Dinner
# sex
# Male    595.60  2661.22  18.048485  21.461452
# Female  571.87   999.08  16.339143  19.213077

# %%
df_tips.pivot_table(
    index='sex',
    columns='time',
    aggfunc=['sum', 'mean'],
    values=['total_bill', 'tip']
)
# Out:
#           sum                                  mean                       \
#           tip         total_bill                tip           total_bill
# time    Lunch  Dinner      Lunch   Dinner     Lunch    Dinner      Lunch
# sex
# Male    95.11  389.96     595.60  2661.22  2.882121  3.144839  18.048485
# Female  90.40  156.11     571.87   999.08  2.582857  3.002115  16.339143
#
#
#
# time       Dinner
# sex
# Male    21.461452
# Female  19.213077

# %%
df_tips.pivot_table(
    index=['day', 'smoker'],
    columns='time',
    aggfunc=['sum', 'mean'],
    values=['total_bill', 'tip']
).fillna(0)
# Out:
#                 sum                                  mean            \
#                 tip         total_bill                tip
# time          Lunch  Dinner      Lunch   Dinner     Lunch    Dinner
# day  smoker
# Thur Yes      51.51    0.00     326.24     0.00  3.030000  0.000000
#      No      117.32    3.00     751.31    18.78  2.666364  3.000000
# Fri  Yes      13.68   27.03      73.94   178.26  2.280000  3.003333
#      No        3.00    8.25      15.98    57.70  3.000000  2.750000
# Sat  Yes       0.00  120.77       0.00   893.62  0.000000  2.875476
#      No        0.00  139.63       0.00   884.78  0.000000  3.102889
# Sun  Yes       0.00   66.82       0.00   458.28  0.000000  3.516842
#      No        0.00  180.57       0.00  1168.88  0.000000  3.167895
#
#
#             total_bill
# time             Lunch     Dinner
# day  smoker
# Thur Yes     19.190588   0.000000
#      No      17.075227  18.780000
# Fri  Yes     12.323333  19.806667
#      No      15.980000  19.233333
# Sat  Yes      0.000000  21.276667
#      No       0.000000  19.661778
# Sun  Yes      0.000000  24.120000
#      No       0.000000  20.506667

# %%
df_tips.pivot_table(index=['day', 'smoker'],
                    columns=['time', 'sex'],
                    aggfunc=['sum', 'mean'],
                    values=['total_bill', 'tip']
                    )
# Out:
#                sum                                                           \
#                tip                       total_bill
# time         Lunch         Dinner             Lunch          Dinner
# sex           Male Female    Male Female       Male  Female    Male  Female
# day  smoker
# Thur Yes     30.58  20.93    0.00   0.00     191.71  134.53    0.00    0.00
#      No      58.83  58.49    0.00   3.00     369.73  381.58    0.00   18.78
# Fri  Yes      5.70   7.98   16.23  10.80      34.16   39.78  129.46   48.80
#      No       0.00   3.00    5.00   3.25       0.00   15.98   34.95   22.75
# Sat  Yes      0.00   0.00   77.74  43.03       0.00    0.00  589.62  304.00
#      No       0.00   0.00  104.21  35.42       0.00    0.00  637.73  247.05
# Sun  Yes      0.00   0.00   52.82  14.00       0.00    0.00  392.12   66.16
#      No       0.00   0.00  133.96  46.61       0.00    0.00  877.34  291.54
#
#                mean                                                      \
#                 tip                               total_bill
# time          Lunch              Dinner                Lunch
# sex            Male    Female      Male    Female       Male     Female
# day  smoker
# Thur Yes     3.0580  2.990000       NaN       NaN  19.171000  19.218571
#      No      2.9415  2.437083       NaN  3.000000  18.486500  15.899167
# Fri  Yes     1.9000  2.660000  3.246000  2.700000  11.386667  13.260000
#      No         NaN  3.000000  2.500000  3.250000        NaN  15.980000
# Sat  Yes        NaN       NaN  2.879259  2.868667        NaN        NaN
#      No         NaN       NaN  3.256563  2.724615        NaN        NaN
# Sun  Yes        NaN       NaN  3.521333  3.500000        NaN        NaN
#      No         NaN       NaN  3.115349  3.329286        NaN        NaN
#
#
#
# time            Dinner
# sex               Male     Female
# day  smoker
# Thur Yes           NaN        NaN
#      No            NaN  18.780000
# Fri  Yes     25.892000  12.200000
#      No      17.475000  22.750000
# Sat  Yes     21.837778  20.266667
#      No      19.929063  19.003846
# Sun  Yes     26.141333  16.540000
#      No      20.403256  20.824286

# %%
df_grouped.size()
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
df_tips.groupby(by=['sex', 'time']).size()
# Out:
# sex     time
# Male    Lunch      33
#         Dinner    124
# Female  Lunch      35
#         Dinner     52
# dtype: int64

# %%
df_tips.pivot_table(
    index='sex',
    columns='time',
    aggfunc='size'
)
# Out:
# time    Lunch  Dinner
# sex
# Male       33     124
# Female     35      52
